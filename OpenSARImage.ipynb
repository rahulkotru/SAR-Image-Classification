# %%
import gdal
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
C11=gdal.Open('D:/GeoSpatial/New folder/c11.bin')

# %%
type(C11)
# Out:
# osgeo.gdal.Dataset

# %%
C11_as_array=C11.ReadAsArray()

# %%
type(C11_as_array)
# Out:
# numpy.ndarray

# %%
np.savetxt("C11_as_array.csv",C11_as_array,delimiter=",")

# %%
np.shape(C11_as_array)
# Out:
# (797, 1939)

# %%
plt.plot(C11_as_array)
# Out:
# ...
#  ...]

# %%
C11_as_array
# Out:
# array([[0.08957845, 0.10284704, 0.16644539, ..., 1.534281  , 4.393583  ,
#         1.1895509 ],
#        [0.07980072, 0.1077747 , 0.0949809 , ..., 0.6502516 , 4.1240315 ,
#         3.2351923 ],
#        [0.12515113, 0.11418435, 0.09721272, ..., 0.17537604, 0.7802419 ,
#         1.8801531 ],
#        ...,
#        [0.04122597, 0.08161703, 0.17156701, ..., 0.05891292, 0.08028976,
#         0.01987679],
#        [0.11088961, 0.12519275, 0.09307268, ..., 0.1341797 , 0.04496468,
#         0.02192933],
#        [0.14909957, 0.09150619, 0.07741938, ..., 0.12644838, 0.05295387,
#         0.0324395 ]], dtype=float32)

# %%
# Out:
# tuple
